# %%
import geolime as geo

collar = geo.datasets.load("/home/mcunningham/gitrepository/pama/data/collar_pama.csv")
survey = geo.datasets.load("/home/mcunningham/gitrepository/pama/data/survey_pama.csv")
assay = geo.datasets.load("/home/mcunningham/gitrepository/pama/data/assay_pama.csv")

collar.head()
# Out:
#    hole_id         x          y        z  totallength
# 0  YNDD003  684836.9  98737.730  383.809       281.05
# 1  YNDD001  684760.4  98709.540  386.653       240.10
# 2  YNDD004  684519.8  98572.516  393.824        87.00
# 3  LNDD001  684188.5  98523.780  418.696       177.10
# 4  BLDD006  685167.4  98840.414  465.921        75.30

# %%
survey.head()
# Out:
#    hole_id  distance  azimuth  dip
# 0  YNDD001         0        0  -90
# 1  YNDD004         0        0  -90
# 2  LNDD001         0        0  -90
# 3  BLDD002         0        0  -90
# 4  BLDD001         0        0  -90

# %%
assay.head()
# Out:
#    hole_id   from     to  interval  Au_ppm  Ag_ppm  As_ppm  Li_ppm   S_ppm
# 0  LNDD001  36.80  37.75      0.95   0.240    0.30   174.0    2.70  9590.0  \
# 1  LNDD001  37.75  38.60      0.85   0.090    0.05     0.5    0.05   240.0
# 2  LNDD001  38.60  39.60      1.00   0.175    0.05   143.0    1.00  2650.0
# 3  LNDD001  39.60  40.60      1.00   0.020    0.05   138.0    0.30  1790.0
# 4  LNDD001  55.20  56.20      1.00   0.010    0.05    43.0    0.60   610.0
#
#     SO2_pct  Hf_ppm  Sc_ppm   MnO_pct classification
# 0  1.915990    0.05     2.0  0.444182   Mg Carbonate
# 1  0.047950    0.05     1.0  0.460968   Mg Carbonate
# 2  0.529445    0.05     1.0  0.417066   Mg Carbonate
# 3  0.357625    0.40     0.5  0.242751   Mg Carbonate
# 4  0.121872    0.05     0.5  0.098133   Mg Carbonate

# %%
dh = geo.create_drillholes(
    name="PAMA",
    collar=collar,
    assays=assay,
    survey=survey,
    method="Tangential",
    dip_convention="NEGATIVE"
)
# Out:
# 2024-01-08 14:43:27,099 [INFO] GeoLime Project - |GEOLIME|.decorator.py : Following mapping has been identified: {
#     "HOLEID": "hole_id",
#     "X_COLLAR": "x",
#     "Y_COLLAR": "y",
#     "Z_COLLAR": "z",
#     "AZIMUTH": "azimuth",
#     "DEPTH_SURVEY": "distance",
#     "DIP": "dip",
#     "FROM": "from",
#     "TO": "to"
# }
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dh = geo.create_drillholes(
#       2     name="PAMA",
#       3     collar=collar,
#       4     assays=assay,
#       5     survey=survey,
#       6     method="Tangential",
#       7     dip_convention="NEGATIVE"
#       8 )
#
# File ~/geoenv/lib/python3.10/site-packages/pydantic/decorator.py:40, in validate_arguments.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      38 @wraps(_func)
#      39 def wrapper_function(*args: Any, **kwargs: Any) -> Any:
# ...
