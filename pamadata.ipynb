# %%
import geolime as geo

collar = geo.datasets.load("/home/mcunningham/gitrepository/pama/data/collar_view.csv")
survey = geo.datasets.load("/home/mcunningham/gitrepository/pama/data/survey_view.csv")
assay = geo.datasets.load("/home/mcunningham/gitrepository/pama/data/assay_view.csv")

collar.head()
# Out:
#    collarid  hole_id         x          y        z     td campaign
# 0         1  ARC-043  685354.2  99273.630  424.393  100.0      NMR
# 1         2  ARC-046  685431.7  99070.086  449.189  100.0      NMR
# 2         3  BHD-001  685336.2  99288.770  430.374  102.0      NMR
# 3         4  BHD-002  684970.1  99261.250  410.135  119.0      NMR
# 4         5  BHD-003  685113.6  98894.450  463.301  100.0      NMR

# %%
survey.head()
# Out:
#    collarid  hole_id  distance   dip  azimuth
# 0         1  ARC-043       0.0 -90.0      0.0
# 1         1  ARC-043     100.0 -90.0      0.0
# 2         2  ARC-046       0.0 -90.0      0.0
# 3         3  BHD-001       0.0 -55.0     90.0
# 4         3  BHD-001     102.0 -56.0     94.0

# %%
assay.head()
# Out:
#    collarid  hole_id  mfrom  mto  minterval  au ppm rockcode
# 0         2  ARC-046    0.0  1.0        1.0    0.20      NaN
# 1         2  ARC-046    1.0  2.0        1.0    0.20      NaN
# 2         2  ARC-046    2.0  3.0        1.0    0.05      NaN
# 3         2  ARC-046    3.0  4.0        1.0    0.05      NaN
# 4         2  ARC-046    4.0  5.0        1.0    0.05      NaN

# %%
dh = geo.create_drillholes(
    name="PAMA",
    collar=collar,
    assays=assay,
    survey=survey,
    method="Tangential",
    dip_convention="NEGATIVE"
)
# Out:
# 2024-01-20 16:25:13,233 [INFO] GeoLime Project - |GEOLIME|.decorator.py : Following mapping has been identified: {
#     "HOLEID": "hole_id",
#     "X_COLLAR": "x",
#     "Y_COLLAR": "y",
#     "Z_COLLAR": "z",
#     "AZIMUTH": "azimuth",
#     "DEPTH_SURVEY": "distance",
#     "DIP": "dip",
#     "FROM": "mfrom",
#     "TO": "mto"
# }
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dh = geo.create_drillholes(
#       2     name="PAMA",
#       3     collar=collar,
#       4     assays=assay,
#       5     survey=survey,
#       6     method="Tangential",
#       7     dip_convention="NEGATIVE"
#       8 )
#
# File ~/geoenv/lib/python3.10/site-packages/pydantic/decorator.py:40, in validate_arguments.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      38 @wraps(_func)
# ...
